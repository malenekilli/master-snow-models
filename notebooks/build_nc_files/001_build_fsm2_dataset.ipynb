# %%
import xarray as xr
import glob

files = sorted(glob.glob("../data/FSM2/fsm2_sd_*.nc"))
print(files)

datasets = [xr.open_dataset(f) for f in files]

fsm2_all = xr.concat(datasets, dim="time")

print(fsm2_all)
# Out:
# []
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/Documents/Skole/Masteroppgave/Master_snow_models/venv/lib/python3.14/site-packages/xarray/structure/concat.py:287, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     286 try:
# --> 287     first_obj, objs = utils.peek_at(objs)
#     288 except StopIteration as err:
#
# File ~/Documents/Skole/Masteroppgave/Master_snow_models/venv/lib/python3.14/site-packages/xarray/core/utils.py:287, in peek_at(iterable)
#     286 gen = iter(iterable)
# --> 287 peek = next(gen)
#     288 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 9
#       5 print(files)
#       7 datasets = [xr.open_dataset(f) for f in files]
# ----> 9 fsm2_all = xr.concat(datasets, dim="time")
#      11 print(fsm2_all)
#
# File ~/Documents/Skole/Masteroppgave/Master_snow_models/venv/lib/python3.14/site-packages/xarray/structure/concat.py:289, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     287     first_obj, objs = utils.peek_at(objs)
#     288 except StopIteration as err:
# --> 289     raise ValueError("must supply at least one object to concatenate") from err
#     291 if not isinstance(compat, CombineKwargDefault) and compat not in set(
#     292     _VALID_COMPAT
#     293 ) - {"minimal"}:
#     294     raise ValueError(
#     295         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     296     )
#
# ValueError: must supply at least one object to concatenate

# %%
from pathlib import Path

Path("../data/processed").mkdir(exist_ok=True)

fsm2_all.to_netcdf("../data/processed/fsm2_sd_all.nc")

# %%
test = xr.open_dataset("../data/processed/fsm2_sd_all.nc")
print(test)
# Out:
# <xarray.Dataset> Size: 11GB
# Dimensions:      (time: 1461, y: 1550, x: 1195)
# Coordinates:
#   * time         (time) datetime64[ns] 12kB 2022-01-01 2022-01-02 ... 2025-12-31
#   * y            (y) float64 12kB 6.45e+06 6.451e+06 ... 7.998e+06 7.999e+06
#   * x            (x) float64 10kB -7.5e+04 -7.4e+04 ... 1.118e+06 1.119e+06
#     lon          (y, x) float64 15MB ...
#     lat          (y, x) float64 15MB ...
# Data variables:
#     snow_depth   (time, y, x) float32 11GB ...
#     UTM_Zone_33  (time) float64 12kB ...
# Attributes:
#     title:        Snow depth
#     institution:  NVE
#     source:       ConvertTo-Grid
#     history:      Initial
#     references:   http://www.xgeo.no/
#     comment:      Snow depth simulated by the FSM2 model run at NVE and force...
#     Conventions:  CF-1.6

# %%
fsm2 = xr.open_dataset("../data/processed/fsm2_sd_all.nc")

# %%
import xarray as xr

fsm = xr.open_dataset("../data/processed/fsm2_sd_all.nc")
print(fsm)
# Out:
# <xarray.Dataset> Size: 11GB
# Dimensions:      (time: 1461, y: 1550, x: 1195)
# Coordinates:
#   * time         (time) datetime64[ns] 12kB 2022-01-01 2022-01-02 ... 2025-12-31
#   * y            (y) float64 12kB 6.45e+06 6.451e+06 ... 7.998e+06 7.999e+06
#   * x            (x) float64 10kB -7.5e+04 -7.4e+04 ... 1.118e+06 1.119e+06
#     lon          (y, x) float64 15MB ...
#     lat          (y, x) float64 15MB ...
# Data variables:
#     snow_depth   (time, y, x) float32 11GB ...
#     UTM_Zone_33  (time) float64 12kB ...
# Attributes:
#     title:        Snow depth
#     institution:  NVE
#     source:       ConvertTo-Grid
#     history:      Initial
#     references:   http://www.xgeo.no/
#     comment:      Snow depth simulated by the FSM2 model run at NVE and force...
#     Conventions:  CF-1.6
